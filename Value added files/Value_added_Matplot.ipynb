# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from numpy import random

# %%
x1=np.array([1,2,3,4,5])
y1=np.array([14,18,8,10,9])
plt.scatter(x1,y1)
plt.title('India')
plt.show()

# %%
x1=np.array([1,2,3,4,5])
y1=np.array([14,18,8,10,9])
plt.scatter(x1,y1)
x2=np.array([1,2,3,4,5])
y2=np.array([10,7,16,19,2])
plt.scatter(x2,y2)
plt.title('Ind vs Aus')
plt.show()
plt.scatter(x1,y1,c='r') 
plt.scatter(x2,y2,c='g')

# %%
x1=np.array([1,2,3,4,5])
y1=np.array([14,18,8,10,9])
c1=np.array(['red','green','blue','orange','magenta'])
plt.scatter(x1,y1,c=c1)
x2=np.array([1,2,3,4,5])
y2=np.array([10,7,16,19,2])
c2=np.array(['cyan','black','grey','brown','pink'])
plt.scatter(x2,y2,c=c2)
plt.title('Ind vs Aus')
plt.show()

# %%
x1=np.array([1,2,3,4,5])
y1=np.array([14,18,8,10,9])
c1=np.array(['red','green','blue','orange','magenta'])
plt.scatter(x1,y1,c=c1,cmap='viridis')
plt.colorbar()
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_2932\3036056107.py:4: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x1,y1,c=c1,cmap='viridis')

# %%
plt.scatter(x1,y1,c=c1,cmap='Accent')
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_2932\3681617769.py:1: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x1,y1,c=c1,cmap='Accent')

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))

# %%
plt.scatter(x, y, c=colors)
plt.show()

# %%
x = np.random.randint(10, size=(10))
y = np.random.randint(10, size=(10))
colors = np.random.randint(10, size=(10))
size=np.array([10,15,20,50,100,30,40,25,55,60])
plt.scatter(x, y, c=colors,s=size)

# %%
plt.scatter(x, y, c=colors,s=size,alpha=0.5)

# %% [markdown]
# # BAR CHART

# %%
a=np.array([1,2,3,4,5])
b=np.array([15,9,11,19,8])
plt.bar(a,b)
plt.show()

# %%
a=np.array([1,2,3,4,5])
b=np.array([15,9,11,19,8])
plt.barh(a,b)
plt.show()

# %%
a=np.array([1,2,3,4,5])
b=np.array([15,9,11,19,8])
plt.bar(a,b,color='green')
plt.show()

# %%
a=np.array([1,2,3,4,5])
b=np.array([15,9,11,19,8])
plt.bar(a,b,width=0.1)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(a,b,height=0.3,color='red')
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# # Histogram
# # It is used for frequency distribution
# # hist() function is used

# %%
import numpy as np
a=np.random.normal(170,10,250)
print(a)
# Out:
# [170.03713134 165.44696523 166.18163627 167.86624089 170.79861755
#  174.69817676 191.14569165 170.19510696 167.31210309 157.37597183
#  168.8767915  168.38184668 177.3632278  170.46103956 174.98767241
#  156.60516326 169.71498001 160.14058482 178.49534883 176.57528495
#  167.80893636 166.18135283 175.59044697 180.47730214 169.04835051
#  169.27632477 173.66582435 170.73700558 170.54484307 185.59668267
#  181.82286463 148.79845226 167.37940559 171.66286332 171.73225369
#  164.83797032 193.35087669 175.46886469 162.17887445 160.06203796]

# %%
plt.hist(a,color='aqua')
plt.show()

# %%
a=np.array([40,25,15,20])
plt.pie(a)
plt.show()

# %%
a=np.array([40,25,15,20])
l=np.array(["Ind","Aus","Eng","Pak"])
plt.pie(a,labels=l)
plt.show()

# %%
plt.pie(a,labels=l,startangle=180)
# Out:
# ([<matplotlib.patches.Wedge at 0x2017a1cca50>,
#   <matplotlib.patches.Wedge at 0x2017a1cd450>,
#   <matplotlib.patches.Wedge at 0x2017a1ce790>,
#   <matplotlib.patches.Wedge at 0x2017a1cfbd0>],
#  [Text(-0.33991867422268845, -1.0461621742897658, 'Ind'),
#   Text(1.086457168210212, 0.17207795223283853, 'Aus'),
#   Text(0.17207785051137706, 1.0864571843213078, 'Eng'),
#   Text(-0.889918748294542, 0.6465637025335368, 'Pak')])

# %%
a=np.array([40,25,15,20])
l=np.array(["Ind","Aus","Eng","Pak"])
ex=[0.2,0.2,0.2,0.2]
plt.pie(a,labels=l,startangle=180,explode=ex)
# Out:
# ([<matplotlib.patches.Wedge at 0x2017889db50>,
#   <matplotlib.patches.Wedge at 0x2017668b790>,
#   <matplotlib.patches.Wedge at 0x2017a2eea50>,
#   <matplotlib.patches.Wedge at 0x2017a2ed990>],
#  [Text(-0.40172206953590456, -1.2363734787060867, 'Ind'),
#   Text(1.2839948351575232, 0.20336485263880918, 'Aus'),
#   Text(0.20336473242253653, 1.2839948541979092, 'Eng'),
#   Text(-1.0517221570753679, 0.7641207393578162, 'Pak')])

# %%
a=np.array([40,25,15,20])
l=np.array(["Ind","Aus","Eng","Pak"])
c=["black","r","#0000FF","aqua"]
ex=[0.2,0.2,0.2,0.2] 
plt.pie(a,labels=l,startangle=180,explode=ex,colors=c)
# Out:
# ([<matplotlib.patches.Wedge at 0x2017a4b9490>,
#   <matplotlib.patches.Wedge at 0x2017a4a5910>,
#   <matplotlib.patches.Wedge at 0x2017a4bab90>,
#   <matplotlib.patches.Wedge at 0x2017a4bb950>],
#  [Text(-0.40172206953590456, -1.2363734787060867, 'Ind'),
#   Text(1.2839948351575232, 0.20336485263880918, 'Aus'),
#   Text(0.20336473242253653, 1.2839948541979092, 'Eng'),
#   Text(-1.0517221570753679, 0.7641207393578162, 'Pak')])

# %%
a=np.array([40,25,15,20])
l=["Ind","Aus","Eng","Pak"]
c=["black","#0000FF","red","aqua"]
plt.pie(a,labels=l,startangle=180,colors=c)
plt.legend(title="Scores")
plt.show()
